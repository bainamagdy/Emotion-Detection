# %%
# %pip install deepface
# Out:
# Collecting deepface
#   Downloading deepface-0.0.93-py3-none-any.whl (108 kB)
#      ------------------------------------ 108.6/108.6 kB 350.0 kB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from deepface) (4.67.1)
# Requirement already satisfied: requests>=2.27.1 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.32.4)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from deepface) (5.2.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from deepface) (3.10.0)
# Collecting gunicorn>=20.1.0
#   Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#      -------------------------------------- 85.0/85.0 kB 191.8 kB/s eta 0:00:00
# Collecting mtcnn>=0.1.0
#   Downloading mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 464.9 kB/s eta 0:00:00
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.19.0)
# Collecting flask-cors>=4.0.1
#   Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Collecting retina-face>=0.0.1
#   Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.3.1)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.1.3)
# Collecting Flask>=1.1.2
#   Downloading flask-3.1.1-py3-none-any.whl (103 kB)
#      ------------------------------------ 103.3/103.3 kB 283.7 kB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from deepface) (4.12.0.88)
# Collecting fire>=0.4.0
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      -------------------------------------- 87.2/87.2 kB 259.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from deepface) (11.3.0)
# Requirement already satisfied: termcolor in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from fire>=0.4.0->deepface) (3.1.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (8.2.1)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (1.9.0)
# Collecting itsdangerous>=2.2.0
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.6)
# Requirement already satisfied: filelock in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from gdown>=3.10.1->deepface) (3.18.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from gdown>=3.10.1->deepface) (4.13.4)
# Requirement already satisfied: packaging in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from gunicorn>=20.1.0->deepface) (25.0)
# Requirement already satisfied: h5py in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from keras>=2.2.0->deepface) (3.14.0)
# Requirement already satisfied: ml-dtypes in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from keras>=2.2.0->deepface) (0.5.1)
# Requirement already satisfied: rich in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from keras>=2.2.0->deepface) (14.0.0)
# Requirement already satisfied: optree in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from keras>=2.2.0->deepface) (0.16.0)
# Requirement already satisfied: namex in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from keras>=2.2.0->deepface) (0.1.0)
# Requirement already satisfied: absl-py in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from keras>=2.2.0->deepface) (2.3.1)
# Collecting lz4>=4.3.3
#   Downloading lz4-4.4.4-cp310-cp310-win_amd64.whl (99 kB)
#      -------------------------------------- 99.9/99.9 kB 319.1 kB/s eta 0:00:00
# Collecting joblib>=1.4.2
#   Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#      ------------------------------------ 307.7/307.7 kB 229.4 kB/s eta 0:00:00
# Requirement already satisfied: tzdata>=2022.7 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23.4->deepface) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23.4->deepface) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23.4->deepface) (2.9.0.post0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->deepface) (2025.6.15)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->deepface) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->deepface) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->deepface) (3.10)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (25.2.10)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.17.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.19.0)
# Requirement already satisfied: setuptools in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (65.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (4.14.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.17.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (5.29.5)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.73.1)
# Requirement already satisfied: colorama in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.45.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=1.9.0->deepface) (3.8.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->deepface) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=2.2.0->deepface) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\baina\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.2)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114262 sha256=becb0cf4da732c8562037683251cb89c9b67b2c598f1d2c273e98c7b2d740a9a
#   Stored in directory: c:\users\baina\appdata\local\pip\cache\wheels\e1\11\25\18200143059912e1b061a3b357bde187caeb4ac892e297c1b7
# Successfully built fire
# Installing collected packages: lz4, joblib, itsdangerous, gunicorn, fire, mtcnn, Flask, flask-cors, retina-face, deepface
# Successfully installed Flask-3.1.1 deepface-0.0.93 fire-0.7.0 flask-cors-6.0.1 gunicorn-23.0.0 itsdangerous-2.2.0 joblib-1.5.1 lz4-4.4.4 mtcnn-1.0.0 retina-face-0.0.17
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%writefile  app.py
import streamlit as st 
from deepface import DeepFace
import cv2 
import numpy as np 
from  PIL import  Image 
import tempfile



## FUNC 

 def analyzeEmation(img_vid):
    try:
       analyze =  DeepFace.analyze(img_vid, actions=["emotion"],enforce_detection=False)
        return analayze[0]['emation']
    except VlueError  as e:
        st.error("Error in analyzing the image or video. Please check the input format.")
        return None


##GUI 

option =st.selectbox("Select Input Type",("Image","Video"))






##MAIN FUNC
if option == "Image":
    uploaded_file = st.file_uploader("Upload an image", type=["jpg", "jpeg", "png"])
    if uploaded_file is not None :
        img = Image.open(uploaded_file)
        img_arr = np.array(img)
        st.image(img, caption="Uploaded Image")
        analyze_result = analyzeEmation(img_arr)
        if analyze_result:
            detect_emotion  = max(analyze_result, key=analyze_result.get)
            st.write(f"Detected Emotion: {detect_emotion}")
        else:       
            st.error("Could not detect emotion from the image.")


if option == "Video":
    uploaded_file = st.file_uploader("Upload a video", type=["mp4", "avi", "mov"])
    if uploaded_file is not None:
        tfiile = tempfile.NamedTemporaryFile(delete=False)
        tfile.write(uploaded_file.read())
        tfile.close()
        video_path = tfile.name
        cap = cv2.VideoCapture(video_path)

    while cap.isOpened():
        frame_count =0 
        frame_rate= 100
        ret,frame =cap.read() 
        if not ret :
            break
        frame_count += 1
        if frame_count % frame_rate == 0:
            img_arr = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            st.image(img_arr, caption="Video Frame")
            analyze_result = analyzeEmation(img_arr)
            if analyze_result:
                detect_emotion = max(analyze_result, key=analyze_result.get)
                st.write(f"Detected Emotion: {detect_emotion}")
            else:
                st.error("Could not detect emotion from the video frame.")
    cap.release()
    st.success("Video processing completed.")
# Out:
# Writing app.py
